# %%
 # Dependencies and Setup
import pandas as pd
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "momPOGstuff.csv"

# Read Purchasing File and store into Pandas data frame
pog_data = pd.read_csv(file_to_load)

# %%
pog_data.head()
# Out:
#    POD_ID                         Sign_Name  \
# 0   34242  1.5x3.25_Arrow_Sticker_rev.08-20
# 1   34241  1.5x3.25_Arrow_Sticker_rev.08-20
# 2   34240  1.5x3.25_Arrow_Sticker_rev.08-20
# 3   34357  1.5x3.25_Arrow_Sticker_rev.08-20
# 4   33501              104702_Dewalt_5x8_V2
#
#                                            Store_num
# 0  5403 , 5413 , 5433 , 5444 , 5445 , 5455 , 5465...
# 1  5405 , 5406 , 5410 , 5411 , 5412 , 5425 , 5432...
# 2  5404 , 5416 , 5460 , 5494 , 5505 , 5513 , 5514...
# 3                                               5647
# 4  5403 , 5404 , 5405 , 5406 , 5410 , 5411 , 5412...

# %%
import numpy as np
from itertools import chain

# return list from series of comma-separated strings
def chainer(s):
    return list(chain.from_iterable(s.str.split(',')))

# calculate lengths of splits
lens = pog_data['Store_num'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
res = pd.DataFrame({'POD_ID': np.repeat(pog_data['POD_ID'], lens),
                    'Sign_Name': np.repeat(pog_data['Sign_Name'], lens),
                    'Store_num': chainer(pog_data['Store_num'])})

res
# Out:
#       POD_ID                         Sign_Name Store_num
# 0      34242  1.5x3.25_Arrow_Sticker_rev.08-20     5403
# 0      34242  1.5x3.25_Arrow_Sticker_rev.08-20     5413
# 0      34242  1.5x3.25_Arrow_Sticker_rev.08-20     5433
# 0      34242  1.5x3.25_Arrow_Sticker_rev.08-20     5444
# 0      34242  1.5x3.25_Arrow_Sticker_rev.08-20     5445
# ...      ...                               ...       ...
# 1370   34480       46x12_Warner_Ladders_Header     5685
# 1370   34480       46x12_Warner_Ladders_Header     5690
# 1370   34480       46x12_Warner_Ladders_Header     5691
# 1370   34480       46x12_Warner_Ladders_Header     5693
# 1370   34480       46x12_Warner_Ladders_Header      5695
#
# [28070 rows x 3 columns]

# %%
res.to_csv('momsFinalPogSignStore.csv')
